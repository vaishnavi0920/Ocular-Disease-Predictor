# %% [markdown]
# # CNN MODEL AND EFFICIENT NET

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import warnings
import cv2
import os
from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix
warnings.filterwarnings('ignore')
# !pip install visualkeras
import visualkeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
#
# Collecting visualkeras
#
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
#
# Collecting aggdraw>=1.3.11
#
#   Downloading aggdraw-1.3.15-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (989 kB)
#
#      |████████████████████████████████| 989 kB 13.0 MB/s
#
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.21.6)
#
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (7.1.2)
#
# Installing collected packages: aggdraw, visualkeras
#
# Successfully installed aggdraw-1.3.15 visualkeras-0.0.2

# %%
# generating dataset from directory

# Generating train dataset
data = tf.keras.utils.image_dataset_from_directory(directory = r'C:\Users\Admin\Downloads\archive (2)\dataset',
                                                   color_mode = 'rgb',
                                                   batch_size = 64,
                                                   image_size = (224,224),
                                                   shuffle=True,
                                                   seed = 2022)
# Out:
# Found 4217 files belonging to 4 classes.

# %% [markdown]
# ## Displaying data distribution

# %%
labels = np.concatenate([y for x,y in data], axis=0)

# %%
values = pd.value_counts(labels)
values = values.sort_index()

# %%
values
# Out:
# 0    1038
# 1    1098
# 2    1007
# 3    1074
# dtype: int64

# %% [markdown]
# ### Checking labels

# %%
# getting class names
class_names = data.class_names
for idx, name in enumerate(class_names):
  print(f"{idx} = {name}", end=", ")
# Out:
# 0 = cataract, 1 = diabetic_retinopathy, 2 = glaucoma, 3 = normal,

# %% [markdown]
# ### The data is well distributed among the classes and is balanced

# %%
plt.figure(figsize=(12,8))
plt.pie(values,autopct='%1.1f%%', explode = [0.02,0.02,0.02, 0.02], textprops = {"fontsize":15})
plt.legend(labels=data.class_names)
plt.show()

# %% [markdown]
# ## Getting a data generator to explore the data

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %% [markdown]
# ### Each batch contains 64 images, each image is 224x224

# %%
batch[0].shape
# Out:
# (64, 224, 224, 3)

# %% [markdown]
# ## Displaying some images

# %%
plt.figure(figsize=(10, 10))
for images, labels in data.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# -----------
# # Preprocessing images

# %% [markdown]
# ## Standardize the data

# %%
data = data.map(lambda x, y: (x/255, y))

# %%
sample = data.as_numpy_iterator().next()

# %%
print(sample[0].min())
print(sample[0].max())
# Out:
# 0.0
#
# 1.0

# %% [markdown]
# ## Spliting the data

# %%
print("Total number of batchs = ",len(data))
# Out:
# Total number of batchs =  66

# %%
train_size = int(0.7 * len(data)) +1
val_size = int(0.2 * len(data))
test_size = int(0.1 * len(data))

# %%
train = data.take(train_size)
remaining = data.skip(train_size)
val = remaining.take(val_size)
test = remaining.skip(val_size)

# %%
print(f"# train batchs = {len(train)}, # validate batchs = {len(val)}, # test batch = {len(test)}")
len(train) + len(val) + len(test)
# Out:
# # train batchs = 47, # validate batchs = 13, # test batch = 6
# 66

# %% [markdown]
# ## Preparing test set

# %%
test_iter = test.as_numpy_iterator()

# %%
test_set = {"images":np.empty((0,224,224,3)), "labels":np.empty(0)}
while True:
  try:
    batch = test_iter.next()
    test_set['images'] = np.concatenate((test_set['images'], batch[0]))
    test_set['labels'] = np.concatenate((test_set['labels'], batch[1]))
  except:
    break

# %%
y_true = test_set['labels']

# %% [markdown]
# ------------
# # CNN from scratch

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten, BatchNormalization
from keras.applications.efficientnet import EfficientNetB3
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam, Adamax

# %%
# Displaying history loss/accuracy
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
def plot_his(history):
    plt.figure(figsize=(15,12))
    metrics = ['accuracy', 'loss']
    for i, metric in enumerate(metrics):
        plt.subplot(220+1+i)
        plt.plot(history.epoch, history.history[metric], color=colors[0], label='Train')
        plt.plot(history.epoch, history.history['val_'+metric],
                 color=colors[1], linestyle="--", label='Val')
        plt.xlabel('Epoch')
        plt.ylabel(metric)
        plt.legend()
    plt.show()

# %% [markdown]
# ### **Here i tried to make the nerual network as deep as i can with keeping the training time and the memory in mind, so we will train it from the scratch and see where we can achieve by this**

# %%
def create_baselineCNN():
    model = Sequential([
        Conv2D(filters = 64, kernel_size=3, activation = 'relu',padding='same', input_shape=(224,224,3)),
        Conv2D(filters = 64, kernel_size=3, activation = 'relu',padding='same'),
        BatchNormalization(),
        MaxPool2D(2),
        Dropout(0.3),

        Conv2D(filters = 128, kernel_size=3,padding='same', activation = 'relu',),
        Conv2D(filters = 128, kernel_size=3,padding='same', activation = 'relu',),
        BatchNormalization(),
        MaxPool2D(2),
        Dropout(0.3),
        
        Conv2D(filters = 128, kernel_size=3,padding='same', activation = 'relu',),
        Conv2D(filters = 128, kernel_size=3,padding='same', activation = 'relu',),
        BatchNormalization(),
        Conv2D(filters = 128, kernel_size=3,padding='same', activation = 'relu',),
        BatchNormalization(),
        MaxPool2D(2),
        Dropout(0.3),
        
        Flatten(),
        Dense(64, activation = 'relu'),
        Dropout(0.3),
        BatchNormalization(),
        Dense(128, activation = 'relu'),
        Dropout(0.3),
        BatchNormalization(),
        Dense(4, activation='softmax')
    ])
    model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), optimizer='adam', metrics=['accuracy'])
    return model

# %%
model = create_baselineCNN()

# %%
model.summary()

visualkeras.layered_view(model,legend=True)
# Out:
# Model: "sequential_9"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  conv2d_63 (Conv2D)          (None, 224, 224, 64)      1792
#
#
#
#  conv2d_64 (Conv2D)          (None, 224, 224, 64)      36928
#
#
#
#  batch_normalization_59 (Bat  (None, 224, 224, 64)     256
#
#  chNormalization)
#
#
#
#  max_pooling2d_27 (MaxPoolin  (None, 112, 112, 64)     0
#
#  g2D)
#
#
#
#  dropout_51 (Dropout)        (None, 112, 112, 64)      0
#
#
#
#  conv2d_65 (Conv2D)          (None, 112, 112, 128)     73856
#
#
#
#  conv2d_66 (Conv2D)          (None, 112, 112, 128)     147584
#
#
#
#  batch_normalization_60 (Bat  (None, 112, 112, 128)    512
#
#  chNormalization)
#
#
#
#  max_pooling2d_28 (MaxPoolin  (None, 56, 56, 128)      0
#
#  g2D)
#
#
#
#  dropout_52 (Dropout)        (None, 56, 56, 128)       0
#
#
#
#  conv2d_67 (Conv2D)          (None, 56, 56, 128)       147584
#
#
#
#  conv2d_68 (Conv2D)          (None, 56, 56, 128)       147584
#
#
#
#  batch_normalization_61 (Bat  (None, 56, 56, 128)      512
#
#  chNormalization)
#
#
#
#  conv2d_69 (Conv2D)          (None, 56, 56, 128)       147584
#
#
#
#  batch_normalization_62 (Bat  (None, 56, 56, 128)      512
#
#  chNormalization)
#
#
#
#  max_pooling2d_29 (MaxPoolin  (None, 28, 28, 128)      0
#
#  g2D)
#
#
#
#  dropout_53 (Dropout)        (None, 28, 28, 128)       0
#
#
#
#  flatten_9 (Flatten)         (None, 100352)            0
#
#
#
#  dense_44 (Dense)            (None, 64)                6422592
#
#
#
#  dropout_54 (Dropout)        (None, 64)                0
#
#
#
#  batch_normalization_63 (Bat  (None, 64)               256
#
#  chNormalization)
#
#
#
#  dense_45 (Dense)            (None, 128)               8320
#
#
#
#  dropout_55 (Dropout)        (None, 128)               0
#
#
#
#  batch_normalization_64 (Bat  (None, 128)              512
#
#  chNormalization)
#
#
#
#  dense_46 (Dense)            (None, 4)                 516
#
#
#
# =================================================================
#
# Total params: 7,136,900
#
# Trainable params: 7,135,620
#
# Non-trainable params: 1,280
#
# _________________________________________________________________
# <PIL.Image.Image image mode=RGBA size=1293x1231 at 0x7F37B9F57610>

# %% [markdown]
# ## Model training
# #### **We will train the Nerual network with 60 epochs and give it an earlystop callback if the accuracy didn't improve much for 20 epochs**

# %%
from keras import callbacks 
early_stop = callbacks.EarlyStopping(
        monitor="val_accuracy", 
        patience=20,
        verbose=1,
        mode="max",
        restore_best_weights=True, 
     )

history = model.fit(
    train,
    validation_data=val,
    epochs = 60,
    callbacks=[early_stop],
)
# Out:
# Epoch 1/60
#
# 47/47 [==============================] - 71s 1s/step - loss: 1.3010 - accuracy: 0.4448 - val_loss: 2.1961 - val_accuracy: 0.2668
#
# Epoch 2/60
#
# 47/47 [==============================] - 65s 1s/step - loss: 0.9731 - accuracy: 0.5575 - val_loss: 4.2651 - val_accuracy: 0.2548
#
# Epoch 3/60
#
# 47/47 [==============================] - 64s 1s/step - loss: 0.8129 - accuracy: 0.6546 - val_loss: 7.0836 - val_accuracy: 0.2512
#
# Epoch 4/60
#
# 47/47 [==============================] - 65s 1s/step - loss: 0.7209 - accuracy: 0.7094 - val_loss: 7.0175 - val_accuracy: 0.2608
#
# Epoch 5/60
#
# 47/47 [==============================] - 65s 1s/step - loss: 0.6556 - accuracy: 0.7301 - val_loss: 7.4071 - val_accuracy: 0.2476
#
# Epoch 6/60
#
# 47/47 [==============================] - 64s 1s/step - loss: 0.6178 - accuracy: 0.7304 - val_loss: 8.0807 - val_accuracy: 0.2620
#
# Epoch 7/60
#
# 47/47 [==============================] - 63s 1s/step - loss: 0.5613 - accuracy: 0.7703 - val_loss: 2.5567 - val_accuracy: 0.3450
#
# Epoch 8/60
#
# 47/47 [==============================] - 64s 1s/step - loss: 0.5739 - accuracy: 0.7603 - val_loss: 5.2522 - val_accuracy: 0.3365
#
# Epoch 9/60
#
# 47/47 [==============================] - 63s 1s/step - loss: 0.5039 - accuracy: 0.7876 - val_loss: 6.1180 - val_accuracy: 0.3149
#
# Epoch 10/60
#
# 47/47 [==============================] - 64s 1s/step - loss: 0.4825 - accuracy: 0.7932 - val_loss: 2.9277 - val_accuracy: 0.4026
#
# Epoch 11/60
#
# 47/47 [==============================] - 63s 1s/step - loss: 0.4697 - accuracy: 0.8078 - val_loss: 1.6211 - val_accuracy: 0.4964
#
# Epoch 12/60
#
# 47/47 [==============================] - 62s 1s/step - loss: 0.4546 - accuracy: 0.8088 - val_loss: 0.9623 - val_accuracy: 0.6346
#
# Epoch 13/60
#
# 47/47 [==============================] - 62s 1s/step - loss: 0.4357 - accuracy: 0.8201 - val_loss: 1.0696 - val_accuracy: 0.5829
#
# Epoch 14/60
#
# 47/47 [==============================] - 62s 1s/step - loss: 0.4185 - accuracy: 0.8305 - val_loss: 0.4253 - val_accuracy: 0.8317
#
# Epoch 15/60
#
# 47/47 [==============================] - 64s 1s/step - loss: 0.3977 - accuracy: 0.8381 - val_loss: 0.3994 - val_accuracy: 0.8317
#
# Epoch 16/60
#
# 47/47 [==============================] - 63s 1s/step - loss: 0.3743 - accuracy: 0.8504 - val_loss: 0.4126 - val_accuracy: 0.8413
#
# Epoch 17/60
#
# 47/47 [==============================] - 63s 1s/step - loss: 0.3650 - accuracy: 0.8534 - val_loss: 0.4271 - val_accuracy: 0.8221
#
# Epoch 18/60
#
# 47/47 [==============================] - 63s 1s/step - loss: 0.3523 - accuracy: 0.8580 - val_loss: 0.4188 - val_accuracy: 0.8389
#
# Epoch 19/60
#
# 47/47 [==============================] - 63s 1s/step - loss: 0.3451 - accuracy: 0.8674 - val_loss: 0.4462 - val_accuracy: 0.8221
#
# Epoch 20/60
#
# 47/47 [==============================] - 62s 1s/step - loss: 0.3226 - accuracy: 0.8730 - val_loss: 0.3408 - val_accuracy: 0.8726
#
# Epoch 21/60
#
# 47/47 [==============================] - 63s 1s/step - loss: 0.2943 - accuracy: 0.8823 - val_loss: 0.4871 - val_accuracy: 0.8065
#
# Epoch 22/60
#
# 47/47 [==============================] - 63s 1s/step - loss: 0.3130 - accuracy: 0.8723 - val_loss: 1.0778 - val_accuracy: 0.6983
#
# Epoch 23/60
#
# 47/47 [==============================] - 63s 1s/step - loss: 0.2740 - accuracy: 0.8946 - val_loss: 0.3279 - val_accuracy: 0.8654
#
# Epoch 24/60
#
# 47/47 [==============================] - 64s 1s/step - loss: 0.2866 - accuracy: 0.8903 - val_loss: 0.3617 - val_accuracy: 0.8498
#
# Epoch 25/60
#
# 47/47 [==============================] - 63s 1s/step - loss: 0.2620 - accuracy: 0.8979 - val_loss: 0.3826 - val_accuracy: 0.8654
#
# Epoch 26/60
#
# 47/47 [==============================] - 62s 1s/step - loss: 0.2735 - accuracy: 0.8966 - val_loss: 0.3262 - val_accuracy: 0.8690
#
# Epoch 27/60
#
# 47/47 [==============================] - 62s 1s/step - loss: 0.2430 - accuracy: 0.9059 - val_loss: 0.3510 - val_accuracy: 0.8618
#
# Epoch 28/60
#
# 47/47 [==============================] - 64s 1s/step - loss: 0.2372 - accuracy: 0.9043 - val_loss: 0.3338 - val_accuracy: 0.8714
#
# Epoch 29/60
#
# 47/47 [==============================] - 63s 1s/step - loss: 0.2133 - accuracy: 0.9152 - val_loss: 0.4335 - val_accuracy: 0.8401
#
# Epoch 30/60
#
# 47/47 [==============================] - ETA: 0s - loss: 0.2172 - accuracy: 0.9159Restoring model weights from the end of the best epoch: 20.
#
# 47/47 [==============================] - 63s 1s/step - loss: 0.2172 - accuracy: 0.9159 - val_loss: 0.4731 - val_accuracy: 0.8137
#
# Epoch 30: early stopping

# %%
plot_his(history)

# %% [markdown]
# ## Evaluating the model on the test set

# %%
y_pred = np.argmax(model.predict(test_set['images']), 1)
# Out:
# 12/12 [==============================] - 6s 250ms/step

# %%
print(classification_report(y_true, y_pred, target_names = class_names))
# Out:
#                       precision    recall  f1-score   support
#
#
#
#             cataract       0.82      0.87      0.84        98
#
# diabetic_retinopathy       1.00      1.00      1.00        95
#
#             glaucoma       0.92      0.68      0.78        95
#
#               normal       0.74      0.89      0.81        89
#
#
#
#             accuracy                           0.86       377
#
#            macro avg       0.87      0.86      0.86       377
#
#         weighted avg       0.87      0.86      0.86       377

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(12, 8))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)
plt.xticks(np.arange(4)+.5, class_names, rotation=90)
plt.yticks(np.arange(4)+.5, class_names, rotation=0)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %% [markdown]
# - The model acheived 86% accuracy

# %% [markdown]
# -----------
# # Efficient Net B3

# %%
def make_model():
    effnet = EfficientNetB3(include_top=False, weights="imagenet",input_shape=(224,224,3), pooling='max') 
    effnet.trainable=False
    
    for layer in effnet.layers[83:]:
      layer.trainable=True
    
    x = effnet.output
    x = BatchNormalization()(x)
    x = Dense(1024, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                    bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
    x = Dropout(rate=.45, seed=2022)(x)        
    output=Dense(4, activation='softmax')(x)
    
    model= tf.keras.Model(inputs=effnet.input, outputs=output)
    model.compile(optimizer = 'adamax', loss='sparse_categorical_crossentropy', metrics=['accuracy']) 
    return model

# %%
model = make_model()

# %% [markdown]
# ## Train the Model

# %%
from keras import callbacks 
early_stop = callbacks.EarlyStopping(
        monitor="val_accuracy", 
        patience=10,
        verbose=1,
        mode="max",
        restore_best_weights=True, 
     )

history = model.fit(
    train,
    validation_data=val,
    epochs = 50,
    callbacks=[early_stop],
)
# Out:
# Epoch 1/50
#
# 47/47 [==============================] - 67s 1s/step - loss: 19.0712 - accuracy: 0.6144 - val_loss: 23.8212 - val_accuracy: 0.2608
#
# Epoch 2/50
#
# 47/47 [==============================] - 49s 988ms/step - loss: 13.6643 - accuracy: 0.7543 - val_loss: 12.9307 - val_accuracy: 0.2933
#
# Epoch 3/50
#
# 47/47 [==============================] - 50s 1s/step - loss: 10.5703 - accuracy: 0.8052 - val_loss: 10.0963 - val_accuracy: 0.3702
#
# Epoch 4/50
#
# 47/47 [==============================] - 51s 1s/step - loss: 8.3634 - accuracy: 0.8248 - val_loss: 8.1085 - val_accuracy: 0.4123
#
# Epoch 5/50
#
# 47/47 [==============================] - 49s 1s/step - loss: 6.6561 - accuracy: 0.8481 - val_loss: 6.4073 - val_accuracy: 0.5877
#
# Epoch 6/50
#
# 47/47 [==============================] - 49s 995ms/step - loss: 5.3298 - accuracy: 0.8574 - val_loss: 5.0450 - val_accuracy: 0.7067
#
# Epoch 7/50
#
# 47/47 [==============================] - 49s 997ms/step - loss: 4.2670 - accuracy: 0.8777 - val_loss: 4.0055 - val_accuracy: 0.7740
#
# Epoch 8/50
#
# 47/47 [==============================] - 49s 996ms/step - loss: 3.4456 - accuracy: 0.8826 - val_loss: 3.2243 - val_accuracy: 0.8077
#
# Epoch 9/50
#
# 47/47 [==============================] - 49s 995ms/step - loss: 2.7802 - accuracy: 0.8963 - val_loss: 2.6628 - val_accuracy: 0.8065
#
# Epoch 10/50
#
# 47/47 [==============================] - 50s 1s/step - loss: 2.2652 - accuracy: 0.9059 - val_loss: 2.2398 - val_accuracy: 0.7981
#
# Epoch 11/50
#
# 47/47 [==============================] - 49s 994ms/step - loss: 1.8560 - accuracy: 0.9096 - val_loss: 1.7482 - val_accuracy: 0.8690
#
# Epoch 12/50
#
# 47/47 [==============================] - 49s 1s/step - loss: 1.5092 - accuracy: 0.9262 - val_loss: 1.4610 - val_accuracy: 0.8750
#
# Epoch 13/50
#
# 47/47 [==============================] - 50s 1s/step - loss: 1.2381 - accuracy: 0.9348 - val_loss: 1.2123 - val_accuracy: 0.8942
#
# Epoch 14/50
#
# 47/47 [==============================] - 49s 992ms/step - loss: 1.0538 - accuracy: 0.9275 - val_loss: 1.0295 - val_accuracy: 0.8942
#
# Epoch 15/50
#
# 47/47 [==============================] - 49s 1s/step - loss: 0.8876 - accuracy: 0.9309 - val_loss: 0.8319 - val_accuracy: 0.9147
#
# Epoch 16/50
#
# 47/47 [==============================] - 49s 997ms/step - loss: 0.7484 - accuracy: 0.9388 - val_loss: 0.7897 - val_accuracy: 0.9038
#
# Epoch 17/50
#
# 47/47 [==============================] - 50s 1s/step - loss: 0.6134 - accuracy: 0.9548 - val_loss: 0.6186 - val_accuracy: 0.9291
#
# Epoch 18/50
#
# 47/47 [==============================] - 49s 997ms/step - loss: 0.5450 - accuracy: 0.9531 - val_loss: 0.5898 - val_accuracy: 0.9183
#
# Epoch 19/50
#
# 47/47 [==============================] - 49s 1000ms/step - loss: 0.4803 - accuracy: 0.9538 - val_loss: 0.5564 - val_accuracy: 0.9183
#
# Epoch 20/50
#
# 47/47 [==============================] - 51s 1s/step - loss: 0.4188 - accuracy: 0.9648 - val_loss: 0.4619 - val_accuracy: 0.9375
#
# Epoch 21/50
#
# 47/47 [==============================] - 49s 994ms/step - loss: 0.3885 - accuracy: 0.9614 - val_loss: 0.4777 - val_accuracy: 0.9195
#
# Epoch 22/50
#
# 47/47 [==============================] - 50s 1s/step - loss: 0.3554 - accuracy: 0.9611 - val_loss: 0.4134 - val_accuracy: 0.9303
#
# Epoch 23/50
#
# 47/47 [==============================] - 49s 998ms/step - loss: 0.3293 - accuracy: 0.9604 - val_loss: 0.3852 - val_accuracy: 0.9315
#
# Epoch 24/50
#
# 47/47 [==============================] - 50s 1s/step - loss: 0.3030 - accuracy: 0.9628 - val_loss: 0.3750 - val_accuracy: 0.9375
#
# Epoch 25/50
#
# 47/47 [==============================] - 49s 1s/step - loss: 0.2864 - accuracy: 0.9688 - val_loss: 0.3968 - val_accuracy: 0.9375
#
# Epoch 26/50
#
# 47/47 [==============================] - 52s 1s/step - loss: 0.2664 - accuracy: 0.9711 - val_loss: 0.3948 - val_accuracy: 0.9207
#
# Epoch 27/50
#
# 47/47 [==============================] - 49s 1000ms/step - loss: 0.2555 - accuracy: 0.9727 - val_loss: 0.3417 - val_accuracy: 0.9423
#
# Epoch 28/50
#
# 47/47 [==============================] - 49s 990ms/step - loss: 0.2340 - accuracy: 0.9751 - val_loss: 0.3538 - val_accuracy: 0.9255
#
# Epoch 29/50
#
# 47/47 [==============================] - 49s 997ms/step - loss: 0.2354 - accuracy: 0.9751 - val_loss: 0.3418 - val_accuracy: 0.9363
#
# Epoch 30/50
#
# 47/47 [==============================] - 49s 994ms/step - loss: 0.2302 - accuracy: 0.9731 - val_loss: 0.4963 - val_accuracy: 0.8930
#
# Epoch 31/50
#
# 47/47 [==============================] - 51s 1s/step - loss: 0.2122 - accuracy: 0.9777 - val_loss: 0.3074 - val_accuracy: 0.9351
#
# Epoch 32/50
#
# 47/47 [==============================] - 49s 997ms/step - loss: 0.2271 - accuracy: 0.9717 - val_loss: 0.3356 - val_accuracy: 0.9363
#
# Epoch 33/50
#
# 47/47 [==============================] - 49s 999ms/step - loss: 0.2033 - accuracy: 0.9781 - val_loss: 0.3023 - val_accuracy: 0.9435
#
# Epoch 34/50
#
# 47/47 [==============================] - 50s 1s/step - loss: 0.2211 - accuracy: 0.9711 - val_loss: 0.2835 - val_accuracy: 0.9447
#
# Epoch 35/50
#
# 47/47 [==============================] - 49s 1s/step - loss: 0.2138 - accuracy: 0.9751 - val_loss: 0.2926 - val_accuracy: 0.9459
#
# Epoch 36/50
#
# 47/47 [==============================] - 50s 1s/step - loss: 0.2136 - accuracy: 0.9707 - val_loss: 0.2944 - val_accuracy: 0.9507
#
# Epoch 37/50
#
# 47/47 [==============================] - 49s 993ms/step - loss: 0.2077 - accuracy: 0.9761 - val_loss: 0.2922 - val_accuracy: 0.9483
#
# Epoch 38/50
#
# 47/47 [==============================] - 49s 994ms/step - loss: 0.1922 - accuracy: 0.9771 - val_loss: 0.3025 - val_accuracy: 0.9507
#
# Epoch 39/50
#
# 47/47 [==============================] - 49s 998ms/step - loss: 0.1913 - accuracy: 0.9771 - val_loss: 0.2698 - val_accuracy: 0.9519
#
# Epoch 40/50
#
# 47/47 [==============================] - 49s 997ms/step - loss: 0.1831 - accuracy: 0.9814 - val_loss: 0.3921 - val_accuracy: 0.9147
#
# Epoch 41/50
#
# 47/47 [==============================] - 49s 994ms/step - loss: 0.1894 - accuracy: 0.9774 - val_loss: 0.3332 - val_accuracy: 0.9399
#
# Epoch 42/50
#
# 47/47 [==============================] - 49s 997ms/step - loss: 0.1806 - accuracy: 0.9807 - val_loss: 0.2890 - val_accuracy: 0.9447
#
# Epoch 43/50
#
# 47/47 [==============================] - 49s 995ms/step - loss: 0.1796 - accuracy: 0.9784 - val_loss: 0.3386 - val_accuracy: 0.9315
#
# Epoch 44/50
#
# 47/47 [==============================] - 51s 1s/step - loss: 0.1814 - accuracy: 0.9787 - val_loss: 0.2828 - val_accuracy: 0.9459
#
# Epoch 45/50
#
# 47/47 [==============================] - 49s 1s/step - loss: 0.1658 - accuracy: 0.9860 - val_loss: 0.2875 - val_accuracy: 0.9507
#
# Epoch 46/50
#
# 47/47 [==============================] - 49s 996ms/step - loss: 0.1578 - accuracy: 0.9884 - val_loss: 0.2494 - val_accuracy: 0.9567
#
# Epoch 47/50
#
# 47/47 [==============================] - 49s 1s/step - loss: 0.1647 - accuracy: 0.9837 - val_loss: 0.3345 - val_accuracy: 0.9399
#
# Epoch 48/50
#
# 47/47 [==============================] - 49s 994ms/step - loss: 0.1586 - accuracy: 0.9864 - val_loss: 0.3156 - val_accuracy: 0.9339
#
# Epoch 49/50
#
# 47/47 [==============================] - 49s 998ms/step - loss: 0.1497 - accuracy: 0.9854 - val_loss: 0.2685 - val_accuracy: 0.9435
#
# Epoch 50/50
#
# 47/47 [==============================] - 49s 988ms/step - loss: 0.1511 - accuracy: 0.9880 - val_loss: 0.2937 - val_accuracy: 0.9483

# %%
plot_his(history)

# %% [markdown]
# ## Evaluating the model on test set

# %%
y_pred = np.argmax(model.predict(test_set['images']), 1)
# Out:
# 12/12 [==============================] - 1s 115ms/step

# %%
print(classification_report(y_true, y_pred, target_names = class_names))
# Out:
#                       precision    recall  f1-score   support
#
#
#
#             cataract       0.95      0.96      0.95        98
#
# diabetic_retinopathy       0.99      1.00      0.99        95
#
#             glaucoma       0.87      0.92      0.89        95
#
#               normal       0.91      0.84      0.88        89
#
#
#
#             accuracy                           0.93       377
#
#            macro avg       0.93      0.93      0.93       377
#
#         weighted avg       0.93      0.93      0.93       377

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(12, 8))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)
plt.xticks(np.arange(4)+.5, class_names, rotation=90)
plt.yticks(np.arange(4)+.5, class_names, rotation=0)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %% [markdown]
# - The model acheived 93% accuracy
